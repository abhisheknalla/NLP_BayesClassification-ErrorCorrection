# %% [markdown]
# # Tokenization

# %%
from os import listdir
from os.path import isfile, join
import re
import pandas as pd
import glob
import errno

# %%
tokens = {}

delim = "( )"

def tokenize(sentences):
    for sentence in sentences:
        arr = re.split(r':|;|,|-| ',sentence)
        
        for word in arr:
            word = word.strip("'|)|(|>|<|?|[|]|(|)|{|}")
            
            word = word.strip('"')
        
            if word:
                if word.lower() not in tokens:
                    tokens[word.lower()] = 0
            
                tokens[word.lower()]+= 1
                word = word.lower()

# %%
def tokenize_1(sentence): 
    return re.split(r':|;|,|-| ',sentence) # Naive tokeniser

# %%
def tokenize_corpus(cor):
    return [tokenize_1(sentence) for sentence in cor]

# %%
puncts = "('|;|:|-,!)"
caps = "([A-Z])"
smalls =  "([a-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def read_content(corpus):
    corpus = corpus.replace('\n',' ')
    
    corpus = re.sub(caps + "[.]" + caps +"[.]","\\1<>\\2<>",corpus)
    corpus = re.sub(" "+ caps +"[.]","\\1<>",corpus)
    corpus = re.sub(caps + "[.]" + caps +"[.]"+ caps +"[.]","\\1<>\\2<>\\3<>",corpus)
    corpus = re.sub(websites,"<>\\1",corpus)
    corpus = re.sub(acronyms +" "+ prefixes,"\\1>< \\2",corpus)
    
    corpus = corpus.replace('?',"?><")
    corpus = corpus.replace('!',"!><")
    corpus = corpus.replace('.',".><")
    corpus = corpus.replace("<>",".")
    corpus = corpus.replace(','," ")
    corpus = corpus.replace("--"," "+"-"+"-"+" ")
    
    sentences = corpus.split("><")
    return sentences[:-1]

# %% [markdown]
# # Correcting the text

# %%
from ipy_table import *
sorted_tokens = sorted(tokens.items(), key = lambda x: x[1], reverse=True)
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
init_notebook_mode(connected=True)

new_text = []

by_new_lines = re.compile("\n+")

def corrected_text(x):
    pre = str('')
    
    x = by_new_lines.split(x)
    
    for line in x:
        line = line.split('   ')
        n = len(line)
        
        if n==3:
            if line[-2] != '-':
                if pre != line[1]:
                    pre = line[1]
                    new_text.append(pre)
            else:
                new_text.append('')
        elif n==1:
            new_text.append(line[0])
    
    return "\n".join(new_text)

# %% [markdown]
# # Class Prediction

# %%
class_corr = {}

class_count = {}

err_class = {}

by_new_lines = re.compile("\n+")

def get_class(x):
    line = by_new_lines.split(x)
    n = len(line)
    for i in range(1, n-3):

        if (line[i-1].split(' ')[0] != '.' and line[i].split(' ')[0] != '.' and line[i+1].split(' ')[0] != '.'):
            
            arr = line[i].split('   ')
            arr_len = len(arr)
            if arr_len == 3:      
                if arr[2] not in class_count:
                    
                    class_count[arr[2]] = {}
                    class_corr[arr[2]] = {}
                    err_class[arr[2]] = 0
                
                err_class[arr[2]] += 1

                if (line[i-1].split('   ')[0], arr[0], line[i+1].split('   ')[0]) not in class_corr[arr[2]]:
                    class_corr[arr[2]][(line[i-1].split('   ')[0], arr[0], line[i+1].split('   ')[0])] = arr[1]
                    
                if (line[i-1].split('   ')[0], arr[0], line[i+1].split('   ')[0]) not in class_count[arr[2]]:
                    class_count[arr[2]][(line[i-1].split('   ')[0], arr[0], line[i+1].split('   ')[0])] = 0
                
                class_count[arr[2]][(line[i-1].split('   ')[0], arr[0], line[i+1].split('   ')[0])] += 1

# %% [markdown]
# ## Bigram generator

# %%
bigrams = {}
bigrams_p = {}

def get_bigrams(corpus):
    for sentence in corpus:
        for index, word in enumerate(sentence):
            word = word.strip("'|)|(|<|>|.|?|!")
            if word:
                word = word.lower()
                
                sentence[index] = word
                
                if index > 0:
                    if sentence[index-1]:
                        
                        prev = sentence[index-1]
                        
                        if prev not in bigrams:
                            bigrams[prev] = {}
                        
                        if word not in bigrams[prev]:
                            bigrams[prev][word] = 0 
                        
                        pair = (sentence[index-1],word)
                        
                        bigrams[prev][word] += 1                        
                        
                        if pair not in bigrams_p:
                            bigrams_p[pair] = 0
                        
                        bigrams_p[pair] += 1

# %%
sorted_bigrams = sorted(bigrams_p.items(), key = lambda x: x[1], reverse=True)

sorted_bigrams = sorted_bigrams[:1000] # RAM problems
#display(make_table(sorted_bigrams[:100]))
#iplot([{"x" : ['_'.join(x) for x in list(zip(*sorted_bigrams[:1000]))[0]], "y": list(zip(*sorted_bigrams[:1000]))[1]}])

# %% [markdown]
# ## Trigram generator

# %%
trigrams = {}

trigrams_t = {}

def get_trigrams(corpus):
    for sentence in corpus:
        
        for index, word in enumerate(sentence):
            word = word.strip("'|)|(|<|>|!|?|. ")
            
            if word:
                word = word.lower()
                sentence[index] = word
                
                if index > 1:
                    if sentence[index-2]:    
                        if index > 0:
                            if sentence[index-1]:
                                pair = (sentence[index-2],sentence[index - 1])
                                
                                if pair not in trigrams:
                                    trigrams[pair] = {}
                                
                                if word not in trigrams[pair]:
                                    trigrams[pair][word] = 0
                
                                tier = (sentence[index-2],sentence[index-1],word)
                                trigrams[pair][word] += 1 
                                
                                if tier not in trigrams_t:
                                    trigrams_t[tier] = 0
                                
                                trigrams_t[tier] += 1
                                
                                pair1 = (sentence[index-2],word)
                
                                if pair1 not in trigrams_t:
                                    trigrams_t[pair1] = 0
                                
                                trigrams_t[pair1] += 1

# %%
sorted_trigrams = sorted(trigrams_t.items(), key = lambda x: x[1], reverse=True)

sorted_trigrams = sorted_trigrams[:1000] # RAM problems
#display(make_table(sorted_trigrams[:100]))

# %% [markdown]
# # Probabilities

# %%
import math

def unigram_probs(tokens):
    new_unigrams = {}
    N = sum(tokens.values())
    
    for word in tokens:
        new_unigrams[word] = round(tokens[word] / float(N), 15)
    
    return new_unigrams

# %%
uprobs = unigram_probs(tokens)
sorted_uprobs = sorted(uprobs.items(), key = lambda x:x[1], reverse=True)
hi_uni = sorted_uprobs[:10]
#display(make_table(hi_uni))
low_uni = sorted_uprobs[:-11:-1]

# %%
def bigram_probs(word):
    N = sum(bigrams[word[0]].values())
    count = 0
    
    if word[1] in bigrams[word[0]]:
        count = bigrams[word[0]][word[1]]
    
    return [round(count / float(N),15),count]

# %%
bg_word = sorted(unigram_probs(bigrams['']).items(),key = lambda x:x[1], reverse=True)
hi_probs = bg_word[:10]
low_probs = bg_word[:-11:-1]
#make_table(hi_probs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-0508c90a0bf8> in <module>()
# ----> 1 bg_word = sorted(unigram_probs(bigrams['']).items(),key = lambda x:x[1], reverse=True)
#       2 hi_probs = bg_word[:10]
#       3 low_probs = bg_word[:-11:-1]
#       4 #make_table(hi_probs)
#
# KeyError: ''

# %%
def trigram_probs(word):
    pair = (word[0],word[1])
    N = sum(trigrams[pair].values())
    count = 0
    
    if word[2] in trigram_probs[pair]:
        count = trigrams[pair][word[2]]
    
    return (round(count / float(N),15),count)

# %%
tg_word = sorted(unigram_probs(trigrams[('','')]).items(),key = lambda x:x[1], reverse=True)
hi_probs = tg_word[:10]
low_probs = tg_word[:-11:-1]
#make_table(hi_probs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-de023cf437a5> in <module>()
# ----> 1 tg_word = sorted(unigram_probs(trigrams[('','')]).items(),key = lambda x:x[1], reverse=True)
#       2 hi_probs = tg_word[:10]
#       3 low_probs = tg_word[:-11:-1]
#       4 #make_table(hi_probs)
#
# KeyError: ('', '')

# %% [markdown]
# # Smoothing

# %%
def laplace_smoothing(n_grams):
    n = len(n_grams)
 #   print(n)
    if n==1:
  #      print(n_grams)     
        if n_grams not in unigrams:
            count_value = 1
        else:
            count_value = unigrams[n_grams] + 1
        ans_value = count_value / ((sum(unigrams.values()) + n )* 1.0)  
    if n == 2:
        if n_grams not in bigrams:
            count_value = 1
        else:
            count_value = bigrams[n_grams] + 1
        ans_value = count_value / ((sum(bigrams.values()) + n*(n-1)) * 1.0)
    if n == 3:
        if n not in trigrams:
            count_value = 1
        else:
            count_value = trigrams[n_grams] + 1
        ans_value = count_value / ((sum(bigrams.values()) + n*(n-1)*(n-2)) * 1.0)
    return ans_value


def good_turing(n_grams):
    
    if len(list(n_grams)) == 3:
        if n_grams in trigrams:
#             trigrams[word] + 1
            if trigrams[n_grams] + 1 in freq_class_tri:
                num = (trigrams[n_grams] + 1) * freq_class_tri[trigrams[n_grams] + 1]
            else:
                num = 0
            den = freq_class_tri[trigrams[n_grams]]
            prob = (num/den)/sum(trigrams.values())
        else: 
            count = 1
            if count in freq_class_tri:
                num = (trigrams[n_grams] + 1) * freq_class_tri[trigrams[n_grams] + 1]
            else:
                num = 0
            den = freq_class_tri[trigrams[n_grams]]
            prob = num/den
            
    if len(list(n_grams)) == 2:
        if n_grams in bigrams:
#             trigrams[word] + 1
            if bigrams[n_grams] + 1 in freq_class_bi:
                num = (bigrams[n_grams] + 1) * freq_class_bi[bigrams[n_grams] + 1]
            else:
                num = 0
            print(bigrams[n_grams])
            print(freq_class_bi[bigrams[n_grams]])
            den = freq_class_bi[bigrams[n_grams]]
            
            prob = (num/den)/sum(freq_class_bi.values())
        else: 
            count = 1
            if count in freq_class_bi:
                num = (bigrams[n_grams] + 1) * freq_class_bi[bigrams[n_grams] + 1]
            else:
                num = 0
            den = freq_class_bi[bigrams[n_grams]]
            prob = num/den
            
    return prob

def good_turing_uni(n_grams):
#     print('HERE')
#     print(unigrams)
    if n_grams in unigrams:
        if unigrams[n_grams] + 1 in freq_class_uni:
            prob = ((unigrams[n_grams]+ 1) * freq_class_uni[unigrams[n_grams]] / (freq_class_uni[unigrams[n_grams] ] * 1.0)) / (freq_class_uni[1] * 1.0)
        else:
            prob = 0
    else:
        if 1 in freq_class_uni:
            prob = ((unigrams[n_grams] + 1) * freq_class_uni[unigrams[n_grams]] / ( sum(unigrams.values()) * 1.0))
        else:
            prob = 0

    return prob

def deleted_interpolation(n_grams):
  # perform deleted Interpolation
#     list_grams = list(n_grams)
    n = len(n_grams)
    if n == 1:
        return laplace_smoothing(n_grams)
    if n == 2:
        return 0.7*laplace_smoothing(n_grams) + 0.3*laplace_smoothing((n_grams[1],))
    else:
        return ((0.5)*laplace_smoothing(n_grams) + (0.4)*laplace_smoothing(n_grams[1:3]) + (0.1)*laplace_smoothing((n_grams[2],)))

# %%
train_path = './Data/train.txt'

file = str(train_path)

by_new_lines = re.compile("\n+")

corpus = open(file,'r')

y = corpus.read()

x = corrected_text(y)

x = read_content(x)

get_class(y)

tokenize(x)

cor = tokenize_corpus(x)

get_bigrams(cor)

get_trigrams(cor)

# %% [markdown]
# # Error Detection

# %%
test_path = './Data/dev.txt'


error_dict = {}

x = open(test_path,'r')

x = x.read()

line = by_new_lines.split(x)

for i in range(1,len(line)-3):
    num = 1
    denom = 0
    v = len(tokens)
    if line[i-1].split(' ')[0]!= '.' and line[i].split(' ')[0]!= '.' and line[i+1].split(' ')[0]!= '.':
        
        if (line[i-1], line[i], line[i+1]) in trigrams_t:
            num = num + trigrams_t[(line[i-1],line[i],line[i+1])]
        
        if (line[i-1],line[i+1]) in trigrams_t:
            denom = denom + trigrams_t[(line[i-1],line[i+1])]
        p = (num/(denom+(v*(v-1)*(v-2))))
        
        num = 1
        if (line[i-1],line[i]) in bigrams_p:
            num = num +  bigrams_p[(line[i-1],line[i])]
        denom = 1
        
        if (line[i-1]) in tokens:
            denom = denom + tokens[line[i-1]]      
        p = p + (num/(denom+(v*(v-1))))
        
        if p < 2/((v*(v-1)*(v-2))) + 2/(v*(v-1)) + 2/v:
            if (line[i-1],line[i],line[i+1]) not in error_dict:
                error_dict[(line[i-1],line[i],line[i+1])] = 0
            
            error_dict[(line[i-1],line[i],line[i+1])] += 1

# %% [markdown]
# # Writing results

# %%
x = open(test_path,'r')
test_result = 'dev_results.txt'

fd = open(test_result,'w')
x = x.read()
count = 0
output_text = []

line = by_new_lines.split(x)

fd.write('%s\n' %line[0])

line_len = len(line)

for i in range(1, line_len-3):
    
    if line[i-1].split(' ')[0] != '.' and line[i].split(' ')[0] != '.' and line[i+1].split(' ')[0] != '.':
        if (line[i-1], line[i], line[i+1]) in error_dict:
            
            word = ''
            clas = ''
            corr = ''
            
            ans = -1
            l = -1
            
            for cc in class_count:
                if (line[i-1],line[i],line[i+1]) in class_count[cc]:
                        prob1 = round((class_count[cc][(line[i-1],line[i],line[i+1])])/(err_class[cc]),15)
                        prob2 = round((err_class[cc])/(sum(err_class.values())),15)
                        
                        l = prob1*prob2
                        
                if ans < l:
                    ans = l
                    word = line[i]
                    clas = cc
                    corr = class_corr[cc][(line[i-1],line[i],line[i+1])]
            
            if word:
                fd.write('%s   %s   %s\n' %(word,corr,clas))
            
            else:
                fd.write('%s\n' %(line[i]))
        
        else:
            fd.write('%s\n' %(line[i]))
    
    else:
        fd.write('%s\n' %(line[i]))

fd.close()

# %%
file = test_result

test_correct = './Data/dev_correction_results.txt'

file1 = test_correct

x = open(file,'r')
x = x.read()

y = open(file1,'r')
y = y.read()

count = 0

x = by_new_lines.split(x)
y = by_new_lines.split(y)

for i in range(len(x)):
    if len(x[i].split('   ')) == len(y[i].split('   ')) and len(x[i].split('   '))!= 1:
        print(i, x[i], y[i])
        count += 1

print(count)
# Out:
# 177 the   -   Um the   in   Prep
# 384 for   -   Um for   on   Prep
# 392 the   -   ArtOrDet the   -   ArtOrDet
# 409 -   the   ArtOrDet -   the   ArtOrDet
# 541 can   do not have   Wci can   do not earn   Vm
# 630 is   -   Rloc- is   are   SVA
# 643 -   the   ArtOrDet -   the   ArtOrDet
# 656 it   -   Rloc- it   -   Um
# 657 can   eeconomic   Wform can   -   Um
# 658 not   should not be   Vm not   -   Um
# 663 them   -   Um them   these   Pref
# 670 more   -   Um more   -   Um
# 671 productive   -   Um productive   -   Um
# 705 the   Nevertheless ,   Trans the   However   Trans
# 706 contrary   Nevertheless ,   Trans contrary   However   Trans
# 735 -   the   ArtOrDet -   the   ArtOrDet
# 856 the   -   Rloc- the   the public owner has a part to play   WOinc
# 927 can   can also   WOadv can   can also   WOadv
# 953 necessary   -   Um necessary   ways   Nn
# 1029 -   helps to   V0 -   products   Nn
# 1123 the   -   ArtOrDet the   -   ArtOrDet
# 1222 an   the   ArtOrDet an   with   Prep
# 1249 that   -   Rloc- that   use   Wform
# 1312 is   -   Rloc- is   -   Rloc-
# 1343 have   has   SVA have   has   SVA
# 1415 let   -   Rloc- let   not to say   Wci
# 1478 as   Indeed   Trans as   like   Wci
# 1509 is   has been   Vform is   are   SVA
# 1558 especially   -   Um especially   -   Rloc-
# 1559 in   -   Um in   -   Rloc-
# 1583 also   enables   Wci also   -   Rloc-
# 1585 provide   -   Um provide   -   Rloc-
# 1592 the   -   ArtOrDet the   -   ArtOrDet
# 1653 their   -   Rloc- their   -   Prep
# 1693 problem   the present lack   SVA problem   -   Rloc-
# 1725 to   on   Prep to   on   Prep
# 1785 the   -   ArtOrDet the   -   ArtOrDet
# 1903 future   -   Um future   ;   Trans
# 2031 on   -   Um on   this spending on the aged should   WOinc
# 2032 the   -   Um the   this spending on the aged should   WOinc
# 2072 is   has not been   Vt is   will be   Vt
# 2121 rights   right   Nn rights   right   Nn
# 2233 -   putting them at   Others -   when   Wci
# 2254 have   -   Um have   -   Um
# 2255 to   -   Um to   -   Um
# 2256 be   for use   Wci be   -   Um
# 2257 used   -   Um used   -   Um
# 2259 cater   make up for   Wci cater   -   Um
# 2260 to   -   Um to   -   Um
# 2261 the   -   Um the   -   Um
# 2262 needs   -   Um needs   -   Um
# 2263 of   -   Um of   -   Um
# 2264 the   -   ArtOrDet the   -   Um
# 2272 -   '   Mec -   '   Npos
# 2377 -   a   ArtOrDet -   ,   Mec
# 2388 -   the   ArtOrDet -   the   ArtOrDet
# 2392 concern   concerned   Wform concern   concerned   Wform
# 2409 the   actively and with dignity   WOinc the   -   ArtOrDet
# 2485 design   -   Um design   existing   Vt
# 2492 could   would   Vm could   -   Rloc-
# 2517 -   the   ArtOrDet -   an   ArtOrDet
# 2534 aged   that the aged have made ,   Ssub aged   have the aged   WOinc
# 2623 compare   compared   Vform compare   compared   Vt
# 2702 the   -   ArtOrDet the   -   ArtOrDet
# 2735 the   -   ArtOrDet the   recent   Wci
# 2805 vhtr   The VHTR will require large amounts of money to be spent   WOinc vhtr   -   Rloc-
# 2827 ,   to spend   Vform ,   -   Rloc-
# 3075 -   have   Vt -   since   Ssub
# 3105 current   priority requirement   Wci current   challenge   Wci
# 3161 limit   Limiting   Vform limit   limits   SVA
# 3162 the   -   ArtOrDet the   -   ArtOrDet
# 3268 the   public spending on the aged should not be limited   Wtone the   -   Rloc-
# 3269 ones   public spending on the aged should not be limited   Wtone ones   -   Rloc-
# 3315 as   -   Um as   which   Ssub
# 3370 -   a   ArtOrDet -   who   Others
# 3390 2052   -   Cit 2052   as top priority   WOinc
# 3394 2009   -   Cit 2009   as top priority   WOinc
# 3469 -   the   ArtOrDet -   are   Vform
# 3488 be   -   Rloc- be   have been   Vt
# 3496 -   the   ArtOrDet -   the   ArtOrDet
# 3518 the   -   ArtOrDet the   -   ArtOrDet
# 3728 objected   argued   Wci objected   argued   Wci
# 3733 had   have   Vform had   -   Vt
# 3890 -   ,   Mec -   ,   Mec
# 3967 -   the   ArtOrDet -   the   ArtOrDet
# 3977 -   the   ArtOrDet -   the   ArtOrDet
# 4051 have   has   Vt have   receive   Wci
# 4124 most   lead   SVA most   -   Rloc-
# 4147 such   -   Um such   -   Wform
# 4208 -   the   ArtOrDet -   ,   Srun
# 4256 -   the   ArtOrDet -   the   ArtOrDet
# 4288 raise   rise   Vform raise   increased   Wci
# 4313 rate   by determining its future birth rates   Ssub rate   the government   Wci
# 4351 who   -   Um who   whoa re poor and needy , and who have been   Spar
# 4466 a   easily contented   WOadv a   the task of taking   WOinc
# 4473 take   taking   Vform take   the task of taking   WOinc
# 4487 by   a cause of concern   WOinc by   Nevertheless   Trans
# 4488 the   -   Um the   Nevertheless   Trans
# 4494 of   the nuclear power plant was inappropriately operated   Spar of   Nevertheless   Trans
# 4495 the   a   ArtOrDet the   Nevertheless   Trans
# 4527 further   further researched and developed   WOinc further   through funding further its research and development   WOinc
# 4528 research   further research and development for the super-critical water reactor ( SCWR )   WOinc research   through funding further its research and development   WOinc
# 4529 and   further research and development for the super-critical water reactor ( SCWR )   WOinc and   through funding further its research and development   WOinc
# 4530 development   funding for its further research and development   Wci development   through funding further its research and development   WOinc
# 4544 -   It   Others -   I   Others
# 4608 after   on how to look after parents when they grow old   WOinc after   -   Rloc-
# 4609 their   on how to look after parents when they grow old   WOinc their   -   Rloc-
# 4617 a   instead of channeling public funds into subsidized health care , the money should be put to better use in education or other aspects   Spar a   There was   Sfrag
# 4637 of   -   Rloc- of   -   Rloc-
# 4872 the   -   ArtOrDet the   -   Nn
# 5161 to   They may not be able to pay taxes if they have lost their jobs   WOinc to   -   Rloc-
# 5162 pay   survive   Wci pay   -   Rloc-
# 5250 lead   -   WOinc lead   led   Vt
# 5336 hence   . Hence   Srun hence   Hence , aging   WOadv
# 5380 citizen   citizens   Nn citizen   citizens   Nn
# 5456 we   -   Wtone we   We   Mec
# 5490 -   the   ArtOrDet -   had   Vt
# 5511 which   -   Um which   -   Um
# 5543 ,   -   Mec ,   . This   Srun
# 5544 which   -   Um which   . This   Srun
# 5592 -   in   Prep -   in   Prep
# 5638 it   -   Rloc- it   It   Mec
# 5662 -   the   ArtOrDet -   a   ArtOrDet
# 5667 elder   employment for the elderly   Wci elder   employment of the elderly   Wci
# 5730 and   determine if they carry the ideal genes for the job .   WOinc and   argue   Vt
# 6030 the   -   ArtOrDet the   -   Rloc-
# 6120 but   -   Rloc- but   and   Trans
# 6192 compared   -   Um compared   -   Rloc-
# 6260 -   the   ArtOrDet -   the   ArtOrDet
# 6317 due   -   Rloc- due   began to welcome   Vt
# 6325 ,   -   Um ,   -   Um
# 6326 they   he   Pref they   -   Um
# 6338 the   other areas   Wci the   -   Um
# 6342 this   . In this case ,   Srun this   -   Um
# 6343 case   . In this case ,   Srun case   -   Um
# 6347 aged   -   Um aged   -   Um
# 6356 the   -   ArtOrDet the   -   Um
# 6455 -   1954 (   Mec -   who will be   Ssub
# 6483 surveillance   -   Um surveillance   Surveillance technology should not be banned   Others
# 6484 technology   . Hence , ...   Srun technology   Surveillance technology should not be banned   Others
# 6486 not   -   Um not   Surveillance technology should not be banned   Others
# 6492 exists   exist   Vform exists   is   Vform
# 6497 is   means   Wci is   -   Rloc-
# 6586 waste   VHTR 's waste   Wci waste   energy waste   WOinc
# 6613 made   channelled   Wci made   given   Wci
# 6639 a   countries   Nn a   -   Um
# 6646 the   -   Um the   -   Um
# 6650 the   -   Um the   younger   Wform
# 6707 the   -   ArtOrDet the   the role of government in providing assistance to the elderly , either to show its appreciation or simply to those who are in need , can not be denied   Wtone
# 6708 government   -   Um government   the role of government in providing assistance to the elderly , either to show its appreciation or simply to those who are in need , can not be denied   Wtone
# 6787 -   the   ArtOrDet -   the   ArtOrDet
# 6919 can   -   Vt can   Obviously ,   Trans
# 6960 the   -   ArtOrDet the   -   ArtOrDet
# 7132 the   -   ArtOrDet the   -   ArtOrDet
# 7295 2009   -   Cit 2009   massive   Wci
# 7304 -   the   ArtOrDet -   the   ArtOrDet
# 7403 of   -   Um of   elderly with hearing loss problem   WOinc
# 7404 the   -   Um the   elderly with hearing loss problem   WOinc
# 7427 than   -   Um than   outweigh   Wci
# 7473 -   the   ArtOrDet -   the   ArtOrDet
# 7528 -   the   ArtOrDet -   the   ArtOrDet
# 7648 by   will affect   Wci by   -   Rloc-
# 7650 aging   -   Um aging   -   Rloc-
# 7665 the   with   Wci the   usage of surveillance technology can be strongly argued against ,   Wtone
# 7666 usage   with   Wci usage   usage of surveillance technology can be strongly argued against ,   Wtone
# 7668 surveillance   -   Um surveillance   usage of surveillance technology can be strongly argued against ,   Wtone
# 7696 first   helpful in the   Wci first   -   Srun
# 7698 is   testing for a few years , it has been found that   Others is   -   Srun
# 7700 identify   fy .   Um identify   -   Srun
# 7702 problem   -   Rloc- problem   -   Srun
# 7703 ,   by getting the people   Ssub ,   -   Srun
# 7708 process   -   Rloc- process   -   Srun
# 7742 government   ove workers'skills .   Nn government   the government of Singapore   ArtOrDet
# 7805 -   ; or   Srun -   and   Ssub
# 7862 the   -   ArtOrDet the   -   ArtOrDet
# 7865 on   -   Um on   for   Prep
# 7919 the   -   ArtOrDet the   a   ArtOrDet
# 7994 -   a   ArtOrDet -   a   ArtOrDet
# 8103 -   to   Prep -   to   Trans
# 8161 with   -   Rloc- with   -   Um
# 8416 -   the   ArtOrDet -   the   ArtOrDet
# 8421 the   -   ArtOrDet the   -   ArtOrDet
# 8497 means   -   Um means   -   Um
# 8499 it   to be   Wci it   -   Um
# 8500 is   -   Rloc- is   -   Um
# 8501 able   possible   Wci able   -   Um
# 8502 to   -   Um to   -   Um
# 8521 not   -   Um not   -   Um
# 8522 be   should not be a   Vm be   -   Um
# 8568 2052   -   Cit 2052   -   Rloc-
# 8579 to   benefits   Rloc- to   -   Um
# 8580 the   -   Um the   -   Um
# 8581 elderly   -   Um elderly   -   Um
# 8608 it   these differences   Pref it   they do   Pref
# 8609 does   -   Um does   they do   Pref
# 8633 it   -   Rloc- it   the military   ArtOrDet
# 8652 -   energy production   Others -   power   Others
# 8800 -   the   ArtOrDet -   the   ArtOrDet
# 8824 the   -   ArtOrDet the   -   Rloc-
# 8840 it   they   Pform it   they   Pref
# 8852 it   -   Um it   they are   Nn
# 8853 is   was   Vt is   they are   Nn
# 8932 and   -   Rloc- and   -   Um
# 8933 in   In   Mec in   -   Um
# 8934 the   -   Rloc- the   -   Um
# 8935 context   -   Rloc- context   -   Um
# 8940 ,   The reason is that   Wci ,   -   Um
# 8941 it   -   Rloc- it   -   Um
# 8948 s.   -   Cit s.   -   Rloc-
# 8951 ,   incorrect intext citation   Rloc- ,   -   Rloc-
# 8952 august   incorrect intext citation   Rloc- august   -   Rloc-
# 8953 17   incorrect intext citation   Rloc- 17   -   Rloc-
# 9045 the   -   ArtOrDet the   -   ArtOrDet
# 9147 an   -   ArtOrDet an   -   ArtOrDet
# 9155 showed   shows   Vt showed   also shows   Vt
# 9185 the   this   ArtOrDet the   -   ArtOrDet
# 9246 design   designed   Wci design   designs   Nn
# 9261 however   . However   Srun however   -   Rloc-
# 9273 -   the   Others -   the   ArtOrDet
# 9322 -   the   ArtOrDet -   the   ArtOrDet
# 9341 the   actively and with dignity   WOinc the   these   ArtOrDet
# 9379 public   -   Um public   increasing   Wform
# 9380 spending   -   Um spending   increasing   Wform
# 9420 have   lower health subsidies from the government possible   WOinc have   to generate a lot of profit   Wci
# 9421 a   lower health subsidies from the government possible   WOinc a   to generate a lot of profit   Wci
# 9569 such   Therefore   Trans such   Therefore   Trans
# 9862 not   -   Um not   -   Um
# 9916 aging   -   Um aging   -   Rloc-
# 9918 as   ;   Trans as   -   Rloc-
# 9919 well   and   Trans well   -   Rloc-
# 9930 spent   -   Rloc- spent   -   Rloc-
# 9931 on   toll   Wci on   -   Rloc-
# 9932 the   -   Um the   -   Rloc-
# 9935 the   -   Rloc- the   -   Rloc-
# 9936 expense   -   Rloc- expense   -   Rloc-
# 10295 due   and building   Srun due   -   Rloc-
# 10310 the   -   ArtOrDet the   -   ArtOrDet
# 10318 of   -   Rloc- of   -   Um
# 10343 affects   affect   SVA affects   . This may affect   Srun
# 10346 -   's   Npos -   's   Mec
# 10475 order   -   Rloc- order   -   Rloc-
# 10477 be   -   Rloc- be   -   Rloc-
# 10478 able   -   Rloc- able   -   Rloc-
# 10564 dependency   -   Rloc- dependency   -   Um
# 10565 of   -   Um of   -   Um
# 10566 the   has   Vt the   -   Um
# 10569 the   -   ArtOrDet the   -   Um
# 10786 rest   become   SVA rest   -   Um
# 10787 of   -   Rloc- of   -   Um
# 10791 be   -   Um be   -   Um
# 10794 to   -   Rloc- to   -   Um
# 10795 the   -   ArtOrDet the   -   Um
# 10806 -   .This   Srun -   the   ArtOrDet
# 10885 the   -   ArtOrDet the   -   ArtOrDet
# 10909 provision   such as lead and uranium are provided   WOinc provision   -   Rloc-
# 10943 -   the   ArtOrDet -   the   ArtOrDet
# 11132 -   a   ArtOrDet -   that   Pref
# 11291 -   the   ArtOrDet -   the   ArtOrDet
# 11366 our   -   Um our   people 's   Wtone
# 11368 with   about   Prep with   about   Prep
# 11444 of   -   Um of   elderly   Wci
# 11458 b.   -   Cit b.   -   Cit
# 11459 friedland   and and S   Cit friedland   -   Cit
# 11460 and   and and S   Cit and   -   Cit
# 11461 laura   -   Cit laura   -   Cit
# 11462 summer   Robert B. Friedland and Laura Summer ( 2005 ) , point out   Wtone summer   -   Cit
# 11463 (   Robert B. Friedland and Laura Summer ( 2005 ) , point out   Wtone (   -   Cit
# 11464 2005   -   Cit 2005   -   Cit
# 11643 to   -   Um to   -   Um
# 11644 responsible   -   Um responsible   -   Um
# 11645 ,   -   Um ,   -   Um
# 11646 prevention   -   Um prevention   -   Um
# 11647 and   -   Um and   -   Um
# 11648 public   -   Um public   -   Um
# 11669 incline   inclined   Vform incline   inclined   Wform
# 11842 first   Even if you look at them for the first time   WOinc first   it was first   WOinc
# 11907 is   was   Vt is   issues   Nn
# 11970 the   -   ArtOrDet the   in   Wci
# 12021 -   the   ArtOrDet -   would have   Vm
# 12092 the   -   ArtOrDet the   -   ArtOrDet
# 12096 however   . However   Srun however   -   Trans
# 12114 make   the ageing   ArtOrDet make   -   Um
# 12165 the   -   Rloc- the   in the context of a small country such as Singapore , besides taking a diplomatic approach , the country also has to make sure that her economy is strong enough for foreign   Srun
# 12166 context   -   Rloc- context   in the context of a small country such as Singapore , besides taking a diplomatic approach , the country also has to make sure that her economy is strong enough for foreign   Srun
# 12167 of   -   Rloc- of   in the context of a small country such as Singapore , besides taking a diplomatic approach , the country also has to make sure that her economy is strong enough for foreign   Srun
# 12183 make   -   Um make   in the context of a small country such as Singapore , besides taking a diplomatic approach , the country also has to make sure that her economy is strong enough for foreign   Srun
# 12354 that   -   Rloc- that   -   Rloc-
# 12384 to   -   Um to   -   Um
# 12389 they   benefits   Rloc- they   -   Um
# 12390 are   with   Prep are   -   Um
# 12420 -   the   Vt -   the   ArtOrDet
# 12497 -   the   ArtOrDet -   the   ArtOrDet
# 12515 so   -   Um so   -   Rloc-
# 12516 as   -   Rloc- as   -   Rloc-
# 12526 spreading   economic development   Wci spreading   t   Rloc-
# 12654 lot   many   Wtone lot   -   Um
# 12746 about   -   Prep about   -   Prep
# 12750 go   help ease   Wci go   help ease   Wci
# 12751 against   help ease   Wci against   help ease   Wci
# 12757 which   Around   Rloc- which   -   Rloc-
# 12768 2052   -   Cit 2052   -   Cit
# 12772 2009   -   Cit 2009   -   Cit
# 12890 health   This problem is occurring in Singapore   Wtone health   resources   Nn
# 12948 the   -   Um the   highly hazardous   Wform
# 12949 main   There are two main reasons for that . Firstly   Ssub main   highly hazardous   Wform
# 12976 be   -   Um be   -   Um
# 12980 the   buildings   Nn the   -   Um
# 12983 the   . The   Srun the   -   Um
# 12995 is   -   Um is   -   Um
# 13001 ageing   -   Um ageing   -   Um
# 13008 be   -   Rloc- be   -   Um
# 13019 's   -   Um 's   -   Um
# 13020 development   -   Um development   -   Um
# 13026 ageing   -   Um ageing   -   Um
# 13057 2004   -   Um 2004   -   Mec
# 13073 ,   Nowadays , the elderly   Wci ,   In the new reactor   Trans
# 13146 able   possible   Wci able   -   Rloc-
# 13171 the   -   ArtOrDet the   the government can not be relied on   Wci
# 13198 for   such as   Wci for   -   Rloc-
# 13199 example   -   Um example   -   Rloc-
# 13377 they   benefits   Rloc- they   he/she   Pref
# 13378 are   -   Um are   is   SVA
# 13543 the   -   Rloc- the   -   Um
# 13547 it   -   Rloc- it   -   Um
# 13558 to   for   Wci to   -   Um
# 13559 the   -   Um the   -   Um
# 13560 elderly   -   Um elderly   -   Um
# 13562 near   the   ArtOrDet near   -   Um
# 13623 they   -   Rloc- they   -   Rloc-
# 13643 from   -   Cit from   -   Rloc-
# 13644 this   -   Cit this   -   Rloc-
# 13645 ,   -   Rloc- ,   -   Rloc-
# 13662 -   the   ArtOrDet -   the   ArtOrDet
# 13695 working   -   Rloc- working   -   Um
# 13707 can   the ticking clock in our body can not be stopped   Wtone can   could   Mec
# 13785 of   -   Um of   worse   Vt
# 13794 -   the   ArtOrDet -   the   ArtOrDet
# 13803 -   the   ArtOrDet -   the coolants used in   Spar
# 13838 introduction   -   Cit introduction   -   Rloc-
# 13859 retirement   Extending the retirement age   Trans retirement   -   Um
# 13864 a   -   Rloc- a   -   Um
# 13868 however   . However ,   Srun however   -   Um
# 13869 ,   -   Trans ,   -   Um
# 13883 an   -   Um an   some   Wci
# 13943 leads   leading   Vform leads   comes   Wci
# 13971 elder   the elderly   Wci elder   the aged   Others
# 14066 to   on   Prep to   on   Prep
# 14165 to   many old people may not be in poor health..   Wci to   -   Rloc-
# 14249 -   an   ArtOrDet -   an   ArtOrDet
# 14264 -   the   ArtOrDet -   an   ArtOrDet
# 14342 the   -   ArtOrDet the   -   ArtOrDet
# 14403 standard   high living standards   Nn standard   living standards   Nn
# 14500 the   -   ArtOrDet the   -   ArtOrDet
# 14503 regards   according   Wci regards   regarding   Wform
# 14664 development/policies   countries that haveproble   Ssub development/policies   development and policies   Trans
# 14677 but   -   Um but   -   WOinc
# 14690 as   -   Um as   expected   Vt
# 14739 -   people   Wci -   person   Others
# 14792 are   is evidence   SVA are   is   SVA
# 14797 been   have   SVA been   -   Rloc-
# 14933 -   the   ArtOrDet -   the   ArtOrDet
# 14983 the   -   ArtOrDet the   -   ArtOrDet
# 14996 human   humans   Nn human   humans   Nn
# 15018 the   -   ArtOrDet the   -   ArtOrDet
# 15062 a   -   Um a   the   ArtOrDet
# 15069 be   are   Vt be   are   Wci
# 15094 is   maintain   Vt is   -   Um
# 15097 of   they are being accepted   Wci of   -   Um
# 15098 the   -   ArtOrDet the   -   Um
# 15102 the   -   Um the   -   Um
# 15193 it   -   Rloc- it   they   Pform
# 15316 it   they are   Pref it   they are   Spar
# 15362 order   -   Rloc- order   are   SVA
# 15390 there   -   Rloc- there   they   Wform
# 15418 -   the   ArtOrDet -   an   ArtOrDet
# 15475 to   on   Prep to   on   Prep
# 15494 -   the   ArtOrDet -   the   ArtOrDet
# 15648 it   -   Um it   they   Pref
# 15671 advance   advanced   Wform advance   advanced   Wform
# 15747 -   those of   Spar -   for   Spar
# 15833 -   the   ArtOrDet -   the   ArtOrDet
# 15841 are   with   Prep are   will be   Vt
# 15866 but   -   Rloc- but   affect   Vt
# 15887 -   and   Trans -   the   ArtOrDet
# 16048 -   the   ArtOrDet -   the   ArtOrDet
# 16175 the   our   Pref the   -   ArtOrDet
# 16299 spending   -   Um spending   Spending   Mec
# 16321 -   ,   Srun -   ,   Srun
# 16330 ,   -   Mec ,   -   Wtone
# 16331 the   an   ArtOrDet the   -   Wtone
# 16332 aging   have emerged   Wci aging   -   Wtone
# 16557 -   the   ArtOrDet -   the   ArtOrDet
# 16582 in   in the areas of slowing down the ageing population , Japan and Singapore ,   WOadv in   -   Rloc-
# 16600 younger   , greatly compromising the academic intelligence of the younger generation   WOinc younger   She questioned where the younger generation would get the money from .   Others
# 16603 to   -   Cit to   She questioned where the younger generation would get the money from .   Others
# 16604 get   arrive at   Wci get   She questioned where the younger generation would get the money from .   Others
# 16724 surveillance   Using surveillance technology to track people   Pref surveillance   Surveillance   Mec
# 16790 -   the   ArtOrDet -   the   ArtOrDet
# 16830 old   -   Rloc- old   -   Rloc-
# 16897 -   on   Prep -   that of   Spar
# 16996 as   refers to   Wci as   such as   Wci
# 17142 -   has   Vt -   has   Vform
# 17159 -   the   ArtOrDet -   the   ArtOrDet
# 17182 they   -   Um they   there   Mec
# 17308 the   actively and with dignity   WOinc the   these   ArtOrDet
# 17344 had   has   Vt had   has   Vt
# 17659 elder   elderly   Wform elder   elderly   Wform
# 17688 of   its use   WOinc of   by using   Wci
# 17699 -   , estimated by 2030 ,   Mec -   the   ArtOrDet
# 17710 the   -   Rloc- the   Currently ,   Wci
# 17723 life   lives   Nn life   lives   Nn
# 17754 view   to help   WOinc view   When dealing with   Trans
# 17831 therefore   . Therefore   Srun therefore   and subsequently   Ssub
# 18170 instance   -   ArtOrDet instance   mentions   Vt
# 18317 elder   elderly   Wform elder   elderly   Wform
# 18332 of   -   Rloc- of   -   Rloc-
# 18333 the   such   Wci the   -   Rloc-
# 18336 -   extended   Others -   a   ArtOrDet
# 18402 are   -   Um are   find   Vform
# 18445 that   Keeping our focus on the elderly is only a temporary solution   WOinc that   this   Pref
# 18470 because   Because   Rloc- because   Because   Mec
# 18622 exist   exists   SVA exist   currently , many social policies exist   WOinc
# 18662 -   ,   Srun -   ,   Mec
# 18670 -   of   Trans -   of   Others
# 18688 researches   research   Wform researches   research   Wform
# 18697 the   -   ArtOrDet the   -   ArtOrDet
# 18707 if   . If   Srun if   -   Rloc-
# 18709 should   -   Um should   -   Rloc-
# 18710 be   -   Um be   -   Rloc-
# 18771 on   -   Prep on   -   Um
# 18772 the   his or her way when finding a   Sfrag the   -   Um
# 18773 way   undergoing   Wci way   -   Um
# 18847 government   -   Rloc- government   has   SVA
# 18861 the   Nevertheless ,   Trans the   However   Trans
# 18862 contrary   Nevertheless ,   Trans contrary   However   Trans
# 19049 this   that   Pref this   -   Rloc-
# 19052 one   -   Um one   -   Rloc-
# 19055 that   if   Ssub that   -   Rloc-
# 19056 the   -   ArtOrDet the   The   Mec
# 19081 old   these sufferings would be reduced   WOinc old   -   Rloc-
# 19082 age   economy of the country and the elderly in saving up more for their old age   WOinc age   -   Rloc-
# 19103 those   -   Um those   the country   Wci
# 19138 on   -   Rloc- on   -   Prep
# 19156 on   -   Um on   -   Rloc-
# 19186 instance   -   ArtOrDet instance   by :   Mec
# 19263 not   -   Um not   younger generations to live in flats close to   WOinc
# 19433 -   mostly   WOadv -   being   Vt
# 19516 the   -   ArtOrDet the   -   ArtOrDet
# 19624 are   is   SVA are   is   SVA
# 19659 's   -   Rloc- 's   -   Npos
# 19663 is   -   Um is   -   Rloc-
# 19673 -   the   ArtOrDet -   the   ArtOrDet
# 19764 the   -   ArtOrDet the   -   Um
# 19765 area   -   Um area   -   Um
# 19773 the   -   ArtOrDet the   -   Um
# 19868 the   politics   Nn the   politics   Nn
# 19978 -   ,   Srun -   ,   Srun
# 20046 -   the   ArtOrDet -   the   ArtOrDet
# 20079 the   -   ArtOrDet the   -   ArtOrDet
# 20115 -   a   ArtOrDet -   a   ArtOrDet
# 20159 -   the   ArtOrDet -   the   ArtOrDet
# 20332 to   for   Prep to   towards   Vt
# 20333 the   a study by economists Laurence Kotlikoff and Christian Hagist of the National Bureau of Economic Research   WOinc the   -   ArtOrDet
# 20391 direct   direct foreign   WOadv direct   -   Rloc-
# 20471 -   a   ArtOrDet -   a   ArtOrDet
# 20500 feel   Therefore ,   Wtone feel   -   Rloc-
# 20527 focus   focused   Vt focus   focused   Vform
# 20601 have   -   SVA have   has   Vt
# 20605 it   -   Rloc- it   not only would the VHTR system benefit ,   WOinc
# 20606 is   -   Um is   not only would the VHTR system benefit ,   WOinc
# 20607 not   needs   Npos not   not only would the VHTR system benefit ,   WOinc
# 20608 only   the only   Ssub only   not only would the VHTR system benefit ,   WOinc
# 20613 benefit   does the country economy benefit , it helps   Vform benefit   not only would the VHTR system benefit ,   WOinc
# 20655 elder   the elderly   Wci elder   the elderly   Npos
# 20676 -   the   ArtOrDet -   the   ArtOrDet
# 20700 they   benefits   Rloc- they   therefore they deserve   Trans
# 20737 -   the   ArtOrDet -   the   ArtOrDet
# 20791 its   -   Rloc- its   -   Rloc-
# 20831 the   -   ArtOrDet the   -   ArtOrDet
# 20904 the   -   Um the   -   Rloc-
# 20905 old   elderly   Wci old   -   Rloc-
# 20919 -   a   ArtOrDet -   the people with a   Others
# 20939 not   -   Um not   -   Rloc-
# 21003 -   the   ArtOrDet -   the   ArtOrDet
# 21073 has   may have   Vm has   should   Vm
# 21084 power   concepts   Nn power   -   Um
# 21089 usage   with   Wci usage   -   Um
# 21125 additional   addition   Trans additional   additionl   Trans
# 21167 elder   employment for the elderly   Wci elder   employment of the elderly   Wci
# 21168 employment   -   Um employment   employment of the elderly   Wci
# 21245 support   -   Um support   -   Rloc-
# 21246 the   -   Um the   -   Rloc-
# 21252 that   why   Wci that   As   WOinc
# 21316 -   .   Vt -   .   Mec
# 21381 's   their   Pref 's   the lives of numerous people   Smod
# 21397 the   -   ArtOrDet the   -   ArtOrDet
# 21457 the   -   ArtOrDet the   its   Pref
# 21544 to   into   Wci to   into   Mec
# 21563 to   with   Wci to   with   Wci
# 21564 have   maintain   Wci have   with   Wci
# 21588 i   -   Um i   they   Pform
# 21635 -   will   Spar -   they are able to   Sfrag
# 21645 opinion   i   Wtone opinion   -   WOinc
# 21737 elders   -   Rloc- elders   usage by the elderly   Npos
# 21751 spend   require   Wci spend   require   Wci
# 21757 building   build   Wform building   to build   Vform
# 21798 however   . However   Srun however   -   Rloc-
# 21799 ,   -   Um ,   -   Rloc-
# 21808 -   ,   Mec -   ,   Mec
# 21987 get   the government can encourage families   Smod get   spent   Vform
# 22032 make   choose a   Wci make   made   Vt
# 22084 -   and   Trans -   the   ArtOrDet
# 22132 one   -   Um one   two   Pref
# 22257 with   -   Rloc- with   by   Prep
# 22297 the   scientists   Rloc- the   to the whole world   Rloc-
# 22298 country   -   Um country   to the whole world   Rloc-
# 22339 the   -   ArtOrDet the   -   ArtOrDet
# 22352 the   with respect to   Wci the   -   Rloc-
# 22353 aspects   with respect to   Wci aspects   -   Rloc-
# 22398 these   -   ArtOrDet these   poor   Pform
# 22417 -   the   ArtOrDet -   the   ArtOrDet
# 22598 it   the problems associated with the aging process are eased to a large extent..   WOinc it   -   Rloc-
# 22698 the   -   ArtOrDet the   -   ArtOrDet
# 22702 it   they   Pform it   they   Pform
# 22724 past   in the past   Wci past   previous   Wci
# 22728 is   are   SVA is   are   SVA
# 22756 -   having   V0 -   when   Ssub
# 22824 final   Employers are able to help their workers by making it compulsory for the latter to reveal their genetic test results..   WOinc final   -   Rloc-
# 22837 that   -   ArtOrDet that   this   Pform
# 22890 of   -   Um of   -   Rloc-
# 22947 it   -   Um it   using accelerators   Pref
# 23019 to   on   Prep to   on   Prep
# 23040 able   -   Um able   restructured   Vt
# 23185 -   ,   Mec -   ,   Mec
# 23196 get   with basic functions that is similar to a basic land line cost thousands   Others get   radically reduce   Wci
# 23204 deal   in dealing   Wci deal   help ease   Wci
# 23231 that   -   Rloc- that   -   Rloc-
# 23283 -   the spreadingof   ArtOrDet -   did   Vm
# 23308 working   work   Wform working   work   Wform
# 23439 country   -   Um country   -   Um
# 23440 's   -   Um 's   -   Um
# 23532 it   they   Pref it   -   Um
# 23533 is   was   Vt is   -   Um
# 23627 -   the   ArtOrDet -   the   ArtOrDet
# 23644 they   -   Rloc- they   it has   Pref
# 23658 acute   -   Um acute   acute-care   Wci
# 23745 the   -   ArtOrDet the   -   ArtOrDet
# 23798 shortage   problems   Wci shortage   problems   Wci
# 23820 -   the   ArtOrDet -   the   ArtOrDet
# 23864 does   -   Um does   petroleum-fuelled   SVA
# 23865 not   provides not only   WOinc not   petroleum-fuelled   SVA
# 23944 instant   instance   Mec instant   instance   Wform
# 24065 not   -   Rloc- not   can not only   WOadv
# 24066 only   -   Rloc- only   can not only   WOadv
# 24169 reduce   reducing   Vform reduce   reduces   SVA
# 24200 suffered   suffer   Vt suffered   suffer   Vt
# 24267 the   -   ArtOrDet the   -   ArtOrDet
# 24269 plant   ago   Mec plant   plants   Nn
# 24283 -   the   ArtOrDet -   the   ArtOrDet
# 24303 -   a   ArtOrDet -   the   ArtOrDet
# 24319 to   expected results   WOinc to   face   SVA
# 24408 the   an   ArtOrDet the   an   ArtOrDet
# 24434 the   -   ArtOrDet the   public funding   Wci
# 24557 -   the   ArtOrDet -   the   ArtOrDet
# 24708 the   this   ArtOrDet the   repeat   Vform
# 24738 on   invest in   Wci on   the elderly ? `` .   Npos
# 24950 to   -   Um to   a   ArtOrDet
# 24951 be   -   Rloc- be   a   ArtOrDet
# 24985 can   could have helped   Vt can   could have helped   Vt
# 24986 help   to allow more people to get the chance to go to school , to improve the standard of education , and to   Trans help   could have helped   Vt
# 25033 energy   ;   Rloc- energy   concepts   Wci
# 25107 -   the   ArtOrDet -   the country 's   Others
# 25125 go   -   Um go   straightaway   Wform
# 25159 the   -   ArtOrDet the   -   ArtOrDet
# 25170 -   ,   Mec -   ,   Cit
# 25325 in   in the United States due to respiratory problems   WOinc in   -   Rloc-
# 25326 the   -   ArtOrDet the   -   Rloc-
# 25349 ability   limit   Wform ability   -   Um
# 25354 which   -   Um which   -   Um
# 25356 not   be enrolled into   Spar not   -   Um
# 25394 we   it can be anticipated that   Wtone we   It can be concluded   Wtone
# 25498 at   make more of an effort to develop the country economically   Um at   -   Rloc-
# 25499 the   -   Rloc- the   -   Rloc-
# 25500 expense   -   Rloc- expense   -   Rloc-
# 25502 the   scientists   Rloc- the   -   Rloc-
# 25503 country   -   Rloc- country   -   Rloc-
# 25515 be   -   Um be   -   Wci
# 25709 -   's   Npos -   's   Npos
# 25832 -   the   ArtOrDet -   the   ArtOrDet
# 25889 can   can only   WOinc can   can only   Wform
# 25945 ,   -   Rloc- ,   -   Rloc-
# 25946 it   -   Rloc- it   -   Rloc-
# 25973 them   .   Mec them   -   Pref
# 26037 their   -   Rloc- their   them   Pref
# 26136 -   ,   Mec -   ,   Mec
# 26220 development   -   Rloc- development   could be stolen or sabotaged by terrorists during transportation or storage   WOinc
# 26221 of   for   Prep of   could be stolen or sabotaged by terrorists during transportation or storage   WOinc
# 26290 it   -   Rloc- it   one   Pref
# 26326 the   -   Um the   -   ArtOrDet
# 26332 -   be   V0 -   be   V0
# 26368 public   -   Um public   -   Rloc-
# 26369 spending   -   Um spending   -   Rloc-
# 26370 is   -   Um is   -   Rloc-
# 26375 elderly   -   Prep elderly   -   Rloc-
# 26388 the   actual   Wci the   -   ArtOrDet
# 26435 -   it   SVA -   this   Pref
# 26528 we   -   Um we   public spending on the aged should not be limited..   Wtone
# 26531 not   public spending on the aged should not be limited   Wtone not   public spending on the aged should not be limited..   Wtone
# 26532 limit   complaints from   Wci limit   public spending on the aged should not be limited..   Wtone
# 26533 the   -   ArtOrDet the   public spending on the aged should not be limited..   Wtone
# 26534 public   -   Um public   public spending on the aged should not be limited..   Wtone
# 26535 spending   -   Um spending   public spending on the aged should not be limited..   Wtone
# 26536 on   -   Um on   public spending on the aged should not be limited..   Wtone
# 26537 the   -   Um the   public spending on the aged should not be limited..   Wtone
# 26547 the   -   ArtOrDet the   -   ArtOrDet
# 26636 been   -   Rloc- been   -   Vt
# 26657 living   -   Um living   cost of living   Wci
# 26683 -   the   ArtOrDet -   the   ArtOrDet
# 26691 increase   in increasing   Wci increase   -   Um
# 26699 increasing   -   Um increasing   the government may increase the total number of people in the workforce and reduce   Sfrag
# 26702 number   -   Rloc- number   the government may increase the total number of people in the workforce and reduce   Sfrag
# 26785 -   has   Vt -   ,   Mec
# 26838 the   its conceptualisation stage   Wci the   -   Rloc-
# 26865 kind   kinds   Nn kind   kinds   Nn
# 26939 does   -   Um does   did   Vt
# 27005 however   . However ,   Srun however   . However ,   Srun
# 27234 economics   economic   Wform economics   economy   Wform
# 27244 working   jobs   Wci working   jobs   Wci
# 27248 they   it   Pref they   it   Pref
# 27280 their   -   Um their   -   Rloc-
# 27314 the   -   ArtOrDet the   -   ArtOrDet
# 27371 the   The fact that `` Families saw the disease destroy their loved ones ' ability to feel , think , and move '' ( MedicineNet.com , n.d. , p.3 ) indicates   Others the   his   ArtOrDet
# 27506 the   a   ArtOrDet the   a   ArtOrDet
# 27529 -   the   ArtOrDet -   the   ArtOrDet
# 27550 the   physicians   Nn the   a   ArtOrDet
# 27694 -   the   ArtOrDet -   and   Srun
# 27708 country   of the country does it portray   WOinc country   -   Um
# 27713 are   common medical procedures are not able to detect   WOinc are   -   Um
# 27725 of   in   Prep of   in   Prep
# 27834 -   the   ArtOrDet -   the   ArtOrDet
# 27964 -   the   ArtOrDet -   the   ArtOrDet
# 27981 -   people   Wci -   individuals   Others
# 28112 the   rising health care costs   Nn the   no need for article   Rloc-
# 28138 in   to   Prep in   to   Prep
# 28622 -   with   Mec -   was   V0
# 28791 of   -   Rloc- of   -   Rloc-
# 28862 -   be   V0 -   being   V0
# 29025 ,   . The   Srun ,   policy makers have played an important role in developing the GPS technology to be what it is today .   Sfrag
# 29026 the   -   ArtOrDet the   policy makers have played an important role in developing the GPS technology to be what it is today .   Sfrag
# 29027 policy   their hard earned money is pent and whether the policy makers are making full use of the money   Others policy   policy makers have played an important role in developing the GPS technology to be what it is today .   Sfrag
# 29031 important   also plays an important part in shaping   WOinc important   policy makers have played an important role in developing the GPS technology to be what it is today .   Sfrag
# 29051 they   small grab poles   Others they   have been   Vt
# 29068 ,   -   Trans ,   ;   Mec
# 29097 only   the only   Ssub only   have   SVA
# 29230 old   the elderly   Wtone old   the elderly   Wci
# 29232 in   -   Rloc- in   the elderly   Wci
# 29233 the   -   Um the   the elderly   Wci
# 29249 order   -   Rloc- order   , though they are constrained by a limited budget to do so   Srun
# 29253 aspects   that the money should be used in other aspects of the society such as education , economic growth and public health care   Ssub aspects   , though they are constrained by a limited budget to do so   Srun
# 29372 ,   . For example   Srun ,   . In fact ,   Srun
# 29407 -   and   Srun -   and   Srun
# 29439 -   the   ArtOrDet -   ( 1992 )   Cit
# 29452 -   an   ArtOrDet -   the   ArtOrDet
# 29521 -   the   ArtOrDet -   the   ArtOrDet
# 29604 &   -   Um &   -   Wa
# 29614 ministry   The research and development and social policies formed by the government are   WOinc ministry   -   Cit
# 29615 of   -   Cit of   -   Cit
# 29616 finance   -   Cit finance   -   Cit
# 29617 of   -   Cit of   -   Cit
# 29618 china   -   Cit china   -   Cit
# 29774 to   aat the same time as lowering health care and freeing up beds in hospitals for more critical cases which need to be treated ( `` Healthcare system to be reconstructed '' , 2009 ) .   Trans to   -   Rloc-
# 29775 be   molten salts are used   WOinc be   -   Rloc-
# 29955 had   has   Vt had   has   Vt
# 30059 with   to   Prep with   to   Prep
# 30285 ,   and the discovery of Warfarin had a different start , process and reasons for success   Srun ,   society   Wci
# 30324 the   -   Rloc- the   -   ArtOrDet
# 30344 to   of causing   Wci to   of   Wci
# 30383 today   -   Um today   us   Rloc-
# 30405 i   One argument is that ,   Wtone i   -   Wtone
# 30406 agree   Therefore , Public   Wtone agree   -   Wtone
# 30411 and   policies mentioned above   Wci and   -   Rloc-
# 30542 she   there are   Pform she   it   Pref
# 30638 sum   sums   Nn sum   sums   Nn
# 30658 been   -   Vt been   were taken   Vform
# 30659 done   must have been made   Wci done   were taken   Vform
# 30680 -   energy production   Others -   power facilities   Others
# 30712 -   for   Wci -   for   Wci
# 30724 design   -   Rloc- design   -   Rloc-
# 30725 process   processes   Nn process   -   Rloc-
# 30727 be   -   Srun be   -   Rloc-
# 30733 it   -   Rloc- it   -   Rloc-
# 30734 is   was   Vt is   -   Rloc-
# 30781 -   the   ArtOrDet -   the   ArtOrDet
# 30830 -   are   Vt -   have   Vt
# 30853 examples   example   Wci examples   example   Trans
# 30881 supports   support   Nn supports   supporters   Wci
# 30899 the   a   ArtOrDet the   -   ArtOrDet
# 30904 the   However ,   Trans the   -   Rloc-
# 30905 other   Despite all the differences   Trans other   -   Rloc-
# 30906 hand   Despite all the differences   Trans hand   -   Rloc-
# 30908 due   and building   Srun due   Due   Mec
# 30952 can   -   Um can   -   Rloc-
# 30956 a   the   ArtOrDet a   -   Rloc-
# 30957 long   theong   ArtOrDet long   -   Rloc-
# 31042 is   was   Vt is   should be   Vm
# 31137 has   also has   WOadv has   also ensures   Vt
# 31143 will   -   Rloc- will   are   Vt
# 31144 be   higher earnings   Wci be   are   Vt
# 31200 could   can   Vm could   -   Um
# 31269 are   tend to be low status jobs like security guards or delivery men .   Um are   can not be reproduced   Vform
# 31286 the   -   ArtOrDet the   -   ArtOrDet
# 31301 the   -   ArtOrDet the   -   Um
# 31302 spending   -   Um spending   -   Um
# 31304 this   -   Rloc- this   -   Um
# 31307 a   ;   Srun a   -   Um
# 31326 faced   face   Vt faced   face   Vt
# 31337 in   on   Prep in   on   WOinc
# 31356 -   putting them at   Others -   introducing   V0
# 31376 in   -   Rloc- in   consequences   Nn
# 31385 them   the   ArtOrDet them   such designs   Others
# 31484 factor   -   Rloc- factor   factors   Nn
# 31491 the   -   ArtOrDet the   -   ArtOrDet
# 31561 disease   diseases   Nn disease   diseases   Wform
# 31802 a   -   Rloc- a   -   Um
# 31805 do   can not   Wci do   -   Um
# 31806 not   -   Um not   -   Um
# 31807 have   Employers are able to help their workers by making it compulsory for the latter to reveal their genetic test results..   WOinc have   -   Um
# 31830 age   aged   Wform age   aged   ArtOrDet
# 31839 day   the aging society   ArtOrDet day   has   Vt
# 31958 the   -   Um the   -   Um
# 31981 many   -   Um many   -   Um
# 31985 -   a   ArtOrDet -   a   ArtOrDet
# 32087 -   so   Trans -   with   Trans
# 32258 however   . However   Srun however   -   Rloc-
# 32259 ,   -   Trans ,   -   Rloc-
# 32308 their   -   Um their   -   Rloc-
# 32333 use   -   Um use   -   Cit
# 32334 of   -   Um of   -   Cit
# 32335 surveillance   -   Um surveillance   -   Cit
# 32336 technology   -   Um technology   -   Cit
# 32337 such   -   Um such   -   Cit
# 32338 as   -   Um as   -   Cit
# 32341 track   -   Um track   -   Cit
# 32455 use   used   Wform use   used   Vform
# 32506 could   would   Vm could   can   Vt
# 32614 the   -   ArtOrDet the   -   ArtOrDet
# 32660 lead   -   WOinc lead   leads   Vt
# 32669 all   -   Um all   sum   Trans
# 32733 had   have   Vt had   have   Vt
# 32744 the   -   ArtOrDet the   -   ArtOrDet
# 32794 -   the   ArtOrDet -   the   ArtOrDet
# 32809 has   have   SVA has   is   Vt
# 32821 we   -   Rloc- we   -   Rloc-
# 32822 are   society is   Wtone are   -   Rloc-
# 32898 -   the   ArtOrDet -   the   ArtOrDet
# 32906 -   and   Trans -   but   Trans
# 33074 out   up   Wci out   up   Wci
# 33086 is   has been   Vform is   -   Rloc-
# 33206 make   based on economic and social considerations   Wci make   restore the land to a livable state   Wci
# 33262 -   putting them at   Others -   on   Prep
# 33395 of   among   Wci of   for   Prep
# 33404 ecommerce   e-commerce   Mec ecommerce   e-commerce   Mec
# 33533 for   . For   Srun for   -   Rloc-
# 33534 instance   -   ArtOrDet instance   -   Rloc-
# 33544 a   -   Um a   -   Rloc-
# 33545 country   -   Um country   -   Rloc-
# 33546 's   -   Um 's   -   Rloc-
# 33547 development   -   Um development   -   Rloc-
# 33591 compare   compared   Vform compare   compared   Vt
# 33630 can   -   Um can   being   Vform
# 33659 consists   consist   SVA consists   -   Rloc-
# 33725 advantages   VHTR has the advantage of   Wci advantages   the advantages of both   WOadv
# 33766 s   MSRs   Mec s   MSRs   Mec
# 33774 -   a   ArtOrDet -   a   Mec
# 33863 in   into   Prep in   on   Prep
# 33905 found   -   Rloc- found   in many developed countries ease   Wci
# 33908 developed   , as well as other issues that concerned   Sfrag developed   in many developed countries ease   Wci
# 33911 easing   ease   Rloc- easing   in many developed countries ease   Wci
# 33939 position   scheme   Wci position   -   Rloc-
# 34114 -   the   ArtOrDet -   the   ArtOrDet
# 34140 -   the   ArtOrDet -   the   ArtOrDet
# 34371 compared   -   Um compared   unlike in   Wci
# 34372 to   its   Pform to   unlike in   Wci
# 34373 the   -   ArtOrDet the   -   ArtOrDet
# 34395 the   to prioritse and balance public funding   Others the   -   ArtOrDet
# 34713 point   leads to another point   Wtone point   this   Wci
# 34714 of   -   Rloc- of   this   Wci
# 34750 get   arrive at   Wci get   develop   Wci
# 34752 development   -   Rloc- development   develop   Wci
# 34753 of   for   Prep of   develop   Wci
# 34775 aged   -   Cit aged   -   Wtone
# 34793 the   -   Rloc- the   -   ArtOrDet
# 34900 ,   -   Um ,   .   Mec
# 34901 which   -   Um which   -   Rloc-
# 34944 elderly   -   Um elderly   for   Wci
# 34963 of   -   Prep of   -   Prep
# 34965 ,   elderly people   Wci ,   are   Wci
# 35045 old-aged   aged   Rloc- old-aged   aged   Rloc-
# 35106 on   -   ArtOrDet on   -   Prep
# 35115 -   the   ArtOrDet -   the   ArtOrDet
# 35519 importance   people are now aware of the importance of finding new , sustainable and eco-friendly energy sources .   WOinc importance   -   Rloc-
# 35521 spending   money to be spent   Wci spending   -   Rloc-
# 35522 on   -   Um on   -   Rloc-
# 35544 it   -   Rloc- it   this   ArtOrDet
# 35545 is   -   Um is   would not be   Vm
# 35561 limited   -   Um limited   rails   Wci
# 35580 -   that   Ssub -   support   Others
# 35874 in   -   Um in   helped   Vt
# 35954 aged   -   Um aged   -   Um
# 35974 kind   -   Um kind   The   ArtOrDet
# 35977 of   provides financial security for   Wci of   for   Prep
# 35981 -   these   Pref -   the   ArtOrDet
# 36142 solution   usage of   Others solution   build   Rloc-
# 36187 out   -   Rloc- out   -   Rloc-
# 36197 of   When asked to investigate the death of a farmer 's cow , a professor   WOinc of   -   Rloc-
# 36198 death   When asked to investigate the death of a farmer 's cow , a professor   WOinc death   -   Rloc-
# 36199 of   When asked to investigate the death of a farmer 's cow , a professor   WOinc of   -   Rloc-
# 36200 his   When asked to investigate the death of a farmer 's cow , a professor   WOinc his   -   Rloc-
# 36255 2009   -   Mec 2009   -   Um
# 36257 from   -   ArtOrDet from   -   Um
# 36258 {   -   Rloc- {   -   Um
# 36259 http   citation   Cit http   -   Um
# 36263 [   -   Cit [   -   Um
# 36264 hyperlink   -   Cit hyperlink   -   Um
# 36288 return   turn   Wci return   -   Sfrag
# 36310 if   -   Um if   -   ArtOrDet
# 36394 they   benefits   Rloc- they   critics   Wform
# 36414 lot   many   Wtone lot   many   Nn
# 36427 united   a most renowned non-profit organisation on applied research in United States known as   Others united   -   Um
# 36468 -   the   ArtOrDet -   the   ArtOrDet
# 36504 fund   funds   Nn fund   funds   Nn
# 36588 at   -   Rloc- at   -   Um
# 36589 the   -   Rloc- the   -   Um
# 36590 same   -   Rloc- same   -   Um
# 36649 are   -   Um are   were   Wci
# 36661 to   with   Wci to   with   Wci
# 36662 have   maintain   Wci have   with   Wci
# 36733 -   the   ArtOrDet -   the   ArtOrDet
# 36783 used   bbanned . They ...   Srun used   use   Wform
# 36794 a   many   Wtone a   -   Rloc-
# 36795 lot   -   Rloc- lot   -   Rloc-
# 36859 nuclear   nuclear   Mec nuclear   materials   Nn
# 36918 high   the Very High   ArtOrDet high   the VHTR   ArtOrDet
# 36919 temperature   -   ArtOrDet temperature   the VHTR   ArtOrDet
# 36920 reactor   -   ArtOrDet reactor   the VHTR   ArtOrDet
# 36929 thus   ; thus ,   Srun thus   . Thus ,   Srun
# 36952 -   the   ArtOrDet -   the   ArtOrDet
# 36966 environmental   environmentally   Wform environmental   environmentally   Wform
# 36978 -   the   ArtOrDet -   a   ArtOrDet
# 37135 however   . However ,   Srun however   According to Khandani ( 2005 )   Wci
# 37199 the   scientists   Rloc- the   a   ArtOrDet
# 37373 for   -   Prep for   -   Prep
# 37402 the   -   ArtOrDet the   -   ArtOrDet
# 37463 -   and   Trans -   there is   Others
# 37567 development/   development , and   Trans development/   development , as well as   Trans
# 37571 a   it can be argued   Wtone a   -   Rloc-
# 37572 large   the problems associated with the aging process are eased to a large extent..   WOinc large   -   Rloc-
# 37573 extent   on a large scale   Wci extent   -   Rloc-
# 37606 role   -   Um role   -   Rloc-
# 37651 not   -   Um not   -   ArtOrDet
# 37664 -   the   ArtOrDet -   the   ArtOrDet
# 37683 citizens   -   Rloc- citizens   -   Rloc-
# 37684 '   -   Rloc- '   -   Rloc-
# 37837 do   -   Rloc- do   not only improves   WOinc
# 37838 not   -   Rloc- not   not only improves   WOinc
# 37842 improve   improving   Vform improve   not only improves   WOinc
# 37973 cost   costs   Nn cost   -   Um
# 37978 a   -   ArtOrDet a   -   Um
# 37984 operating   cents   Nn operating   -   Um
# 37987 a   -   ArtOrDet a   -   Um
# 37989 power   -   ArtOrDet power   -   Um
# 38277 going   -   Um going   -   Um
# 38278 to   -   Um to   -   Um
# 38282 retirement   Extending the retirement age   Trans retirement   -   Um
# 38283 age   Extending the retirement age   Trans age   -   Um
# 38314 of   nuclear accident   Wci of   nuclear plant accident   WOinc
# 38327 help   helped   Vt help   helped   Vt
# 38340 development   -   Um development   capacity   Wci
# 38356 (   -   Um (   -   Um
# 38357 2003   -   Um 2003   -   Um
# 38383 r   -   Um r   -   Wa
# 38384 &   -   Um &   -   Wa
# 38392 -   the   ArtOrDet -   the   ArtOrDet
# 38452 feeling   -   Um feeling   feelings   Wform
# 38458 this   . In this case ,   Srun this   Finally   Trans
# 38498 country   -   Rloc- country   -   Cit
# 38499 's   -   Rloc- 's   -   Cit
# 38514 -   the   ArtOrDet -   the   ArtOrDet
# 38570 -   the   ArtOrDet -   the   ArtOrDet
# 38596 problem   -   Um problem   problems   Nn
# 38614 not   -   Rloc- not   -   Um
# 38616 public   -   Um public   Public   Mec
# 38749 complaints   complaints from the   Wci complaints   complaints from   Wci
# 38796 used   -   Um used   use   Wform
# 38871 not   available   Others not   -   Mec
# 38917 fuels   fuel   Nn fuels   fuel   Nn
# 38934 may   -   Um may   -   Vt
# 38935 be   -   Um be   -   Vt
# 38936 objected   argued   Wci objected   -   Vt
# 38952 the   -   ArtOrDet the   -   Vt
# 39344 usage   with   Wci usage   use   Wci
# 39376 -   and   Srun -   since   Trans
# 39389 the   -   ArtOrDet the   -   ArtOrDet
# 39547 the   -   Um the   have accumulated   Vt
# 39594 of   -   Um of   help   Wci
# 39598 get   with basic functions that is similar to a basic land line cost thousands   Others get   gain   Wci
# 39687 have   analyzed   Vt have   -   Um
# 39688 been   have   SVA been   -   Um
# 39745 bring   brought   Vt bring   brought   Vt
# 39867 -   the   ArtOrDet -   the   ArtOrDet
# 39989 -   to   Prep -   to   Others
# 40001 important   of   Prep important   causes   Vform
# 40068 some   -   Rloc- some   various   Wci
# 40155 also   enables   Wci also   . If successful , they also help organ breakdown   Srun
# 40210 organizations   Organizations   Mec organizations   Organizations   Mec
# 40231 ability   limit   Wform ability   -   Um
# 40466 surveillance   -   Um surveillance   have   SVA
# 40517 -   the   ArtOrDet -   the cost we would have to pay for electricity generated by   Spar
# 40524 the   -   ArtOrDet the   -   ArtOrDet
# 40562 term   terms   Nn term   terms   Wci
# ...
# 42573 -   the   ArtOrDet -   which   Pref
# 42651 with   -   Prep with   the CPF scheme created by the government   WOinc
# 42656 by   -   Um by   the CPF scheme created by the government   WOinc
# 42657 the   make will incur some cost ,   WOinc the   the CPF scheme created by the government   WOinc
# 42762 in   of   Prep in   of   Prep
# 42782 -   the   ArtOrDet -   the   ArtOrDet
# 42920 -   the   ArtOrDet -   the   ArtOrDet
# 43007 out   -   Rloc- out   -   Rloc-
# 43075 affect   have affected   Vt affect   hamper   Wci
# 43198 of   The necessary adjustments or assessments based on the effectiveness of the solutions . can be made   Wtone of   in   Wci
# 43215 the   -   Um the   the future   Wci
# 43279 on   -   Um on   students are taught the values of filial piety   Smod
# 43280 the   -   Um the   students are taught the values of filial piety   Smod
# 43281 aged   -   Um aged   students are taught the values of filial piety   Smod
# 43282 should   -   ArtOrDet should   students are taught the values of filial piety   Smod
# 43283 be   -   Um be   students are taught the values of filial piety   Smod
# 43290 concern   be concerned   Vform concern   be concerned   Vt
# 43390 -   the   ArtOrDet -   The   ArtOrDet
# 43420 -   the   ArtOrDet -   the   ArtOrDet
# 43497 or   They have   Pref or   one   Spar
# 43518 type   types   Nn type   types   Nn
# 43541 -   the   ArtOrDet -   the   ArtOrDet
# 43807 some   -   Um some   Some   Mec
# 43830 -   a   ArtOrDet -   a   ArtOrDet
# 43939 public   -   Um public   Public   ArtOrDet
# 44004 a   -   Um a   Although technological deficiency was behind the failure of the Challenger   Ssub
# 44005 consequence   -   Um consequence   Although technological deficiency was behind the failure of the Challenger   Ssub
# 44091 those   the   ArtOrDet those   such   Wci
# 44108 have   -   Cit have   -   Um
# 44109 shown   -   Cit shown   -   Um
# 44114 able   possible   Wci able   -   Um
# 44115 to   generate   Wci to   -   Um
# 44237 is   .   Rloc- is   was   Vt
# 44246 does   sources   Wci does   did   Vt
# 44344 ease   -   Um ease   in   Wci
# 44449 of   -   Rloc- of   countries   Nn
# 44542 discovery   on   Wci discovery   discoveries   Nn
# 44553 the   One good way to solve this problem   WOinc the   their   Pref
# 44563 be   -   Rloc- be   -   Um
# 44591 is   are   Vform is   -   Rloc-
# 44778 therefore   . Therefore   Srun therefore   . Therefore   Srun
# 44795 the   -   ArtOrDet the   -   ArtOrDet
# 44882 situation   education system   Wci situation   -   Rloc-
# 44923 in   should   Vm in   destructive   Wci
# 45097 are   -   Um are   will be   Vt
# 45112 the   -   ArtOrDet the   -   ArtOrDet
# 45179 feel   Therefore ,   Wtone feel   -   Wtone
# 45180 that   Therefore ,   Wtone that   -   Wtone
# 45199 the   that the money should be used in other aspects of the society such as education , economic growth and public health care   Ssub the   . The money should then   Srun
# 45200 money   that the money should be used in other aspects of the society such as education , economic growth and public health care   Ssub money   . The money should then   Srun
# 45201 should   that the money should be used in other aspects of the society such as education , economic growth and public health care   Ssub should   . The money should then   Srun
# 45212 is   are   SVA is   are   SVA
# 45228 -   the   ArtOrDet -   the   ArtOrDet
# 45239 leading   , this leads   Srun leading   , and thus this leads   Srun
# 45245 the   -   ArtOrDet the   -   ArtOrDet
# 45303 make   right   Nn make   makes   Vt
# 45358 up   -   Rloc- up   -   Um
# 45362 of   -   Rloc- of   -   Um
# 45398 there   -   Rloc- there   systems   Nn
# 45473 -   the   ArtOrDet -   the   ArtOrDet
# 45705 results   are   Vt results   result   Rloc-
# 46027 the   -   ArtOrDet the   -   Rloc-
# 46056 it   -   Rloc- it   they   Pform
# 46328 ,   -   Rloc- ,   surveillance technology   Rloc-
# 46329 it   these differences   Pref it   surveillance technology   Rloc-
# 46375 -   and   Srun -   and   Ssub
# 46446 -   the   ArtOrDet -   the   ArtOrDet
# 46494 that   -   Um that   architectural buildings of our time   Spar
# 46546 -   .   Cit -   .   Cit
# 46549 individual   individuals   Nn individual   individuals   Nn
# 46569 to   -   Prep to   -   Trans
# 46587 social   economic and social factors   Others social   sociology   Wci
# 46623 the   lose   Wci the   these   Pref
# 46642 the   -   ArtOrDet the   least ,   Sfrag
# 46658 process   -   Um process   -   Rloc-
# 46702 the   a   ArtOrDet the   -   ArtOrDet
# 46750 is   has been   Vform is   needs   Wci
# 46792 the   -   ArtOrDet the   -   ArtOrDet
# 46822 they   -   Um they   -   Rloc-
# 46936 the   their   Pref the   -   Rloc-
# 47034 for   -   Um for   economy   Wform
# 47044 using   use   Vform using   -   Rloc-
# 47079 way   how it   WOinc way   involved in the research process   Wci
# 47081 come   generation of innovative ideas   Others come   involved in the research process   Wci
# 47084 technology   In conclusion , with the development of technology , the aging process will become slower   Wtone technology   involved in the research process   Wci
# 47086 they   benefits   Rloc- they   They are ... ecognizing   Srun
# 47171 an   physical changes and limitations   Rloc- an   the   ArtOrDet
# 47257 -   the   ArtOrDet -   the   ArtOrDet
# 47328 the   -   ArtOrDet the   advancements   Nn
# 47329 advancement   -   Um advancement   advancements   Nn
# 47366 -   energy production   Others -   energy   Wci
# 47388 -   the   ArtOrDet -   the   ArtOrDet
# 47409 all   . Afterall ,   Srun all   Therefore   Trans
# 47412 's   -   Um 's   -   Um
# 47413 financial   -   Um financial   -   Um
# 47414 problem   -   Um problem   -   Um
# 47415 in   -   Um in   -   Um
# 47416 economic   -   Um economic   -   Um
# 47988 1033   -   Cit 1033   -   Rloc-
# 48010 an   Lastly   Wci an   the   ArtOrDet
# 48032 are   -   Rloc- are   were   Vt
# 48054 on   about   ArtOrDet on   about   Prep
# 48148 {   -   Cit {   -   Cit
# 48149 http   citation   Cit http   -   Cit
# 48153 [   -   Cit [   -   Cit
# 48154 hyperlink   -   Cit hyperlink   -   Cit
# 48155 :   -   Cit :   -   Cit
# 48156 http   -   Cit http   -   Cit
# 48167 [   -   Cit [   -   Cit
# 48168 hyperlink   -   Cit hyperlink   -   Cit
# 48169 :   -   Cit :   -   Cit
# 48170 http   -   Cit http   -   Cit
# 48214 be   -   Um be   things   Wci
# 48254 is   -   Rloc- is   will still be   Vt
# 48255 still   -   Um still   will still be   Vt
# 48314 -   the   ArtOrDet -   the   Wci
# 48339 of   -   Prep of   -   Prep
# 48457 the   -   ArtOrDet the   -   Prep
# 48599 their   -   Rloc- their   one 's   Spar
# 48727 -   a   ArtOrDet -   a   ArtOrDet
# 48750 pertaining   -   Cit pertaining   on   Wci
# 48763 not   -   Um not   it is not just the facilities that need improvement , but also the treatment of patients..   Sfrag
# 48767 also   will not only find it beneficial to those who are presently young but also for the future elderly population   WOinc also   it is not just the facilities that need improvement , but also the treatment of patients..   Sfrag
# 48769 treatments   treatment   Nn treatments   it is not just the facilities that need improvement , but also the treatment of patients..   Sfrag
# 48773 also   -   Um also   it is not just the facilities that need improvement , but also the treatment of patients..   Sfrag
# 48814 the   -   Rloc- the   threaten the public   Others
# 48818 ,   In addition   Trans ,   Secondly   Wci
# 48819 the   . The   Srun the   Secondly   Wci
# 48840 -   .   Mec -   .   Mec
# 49087 have   has   SVA have   has   SVA
# 49128 due   -   Rloc- due   -   Rloc-
# 49329 -   care   V0 -   the   ArtOrDet
# 49357 are   Many   Rloc- are   is   Vt
# 49404 relying   -   Rloc- relying   -   Um
# 49407 to   -   Um to   -   Um
# 49408 take   taking   Vform take   -   Um
# 49409 care   -   Um care   -   Um
# 49410 of   -   Um of   -   Um
# 49413 they   individuals   Wci they   -   Um
# 49417 thus   such as   Trans thus   . Thus   Srun
# 49436 -   just   Trans -   ,   Srun
# 49557 by   on the part of   Wci by   through   Prep
# 49609 -   a   ArtOrDet -   a   ArtOrDet
# 49735 difference   significant differences in life expectancy and actual lifespan can be seen..   Wtone difference   differences   Nn
# 49840 -   a   ArtOrDet -   a   ArtOrDet
# 49878 it   -   Rloc- it   -   Rloc-
# 49903 example   -   Um example   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49904 ,   -   Um ,   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49905 the   improvements   Nn the   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49906 improvement   improvements   Nn improvement   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49907 of   delete highlighted and replace with 'in '   Wci of   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49915 the   developing   Spar the   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49916 development   -   Rloc- development   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49917 of   for   Prep of   The improvement of the reverse osmosis process that created NeWater and the development of the 'eco-friendly ' vehicles are examples   Sfrag
# 49986 the   -   ArtOrDet the   -   ArtOrDet
# 50117 population   Imagine a situation in which without sufficient support from the government , the aged become a burden to their families..   Wci population   -   Rloc-
# 50122 deal   in dealing   Wci deal   -   Rloc-
# 50128 2007   -   Cit 2007   experience   Nn
# 50263 have   has   SVA have   has   SVA
# 50376 -   environment   Wci -   a conventional   ArtOrDet
# 50416 old   -   Rloc- old   -   Rloc-
# 50452 aged   -   Um aged   -   WOinc
# 50652 this   . This   Srun this   the design   ArtOrDet
# 50661 -   an   Others -   an   ArtOrDet
# 50693 -   the   Um -   the   ArtOrDet
# 50709 therefore   . Therefore ,   Mec therefore   -   Rloc-
# 50711 will   -   Rloc- will   is   Vt
# 50712 be   more people will lose   WOinc be   is   Vt
# 50773 does   -   Um does   did   Vt
# 50776 the   -   ArtOrDet the   its   Pref
# 50784 will   could   Vm will   -   Rloc-
# 50785 be   -   Rloc- be   -   Rloc-
# 50810 -   a   ArtOrDet -   a   ArtOrDet
# 50885 develop   developing   Vform develop   of developing   Wci
# 50891 using   the use of   Wci using   the use of   Wci
# 50990 implements   implementing   Vform implements   implement   Vform
# 51232 result   a   ArtOrDet result   the purchase of   Wform
# 51280 nuclear   -   Rloc- nuclear   nuclear   Mec
# 51305 -   the   ArtOrDet -   the   ArtOrDet
# 51331 it   -   Rloc- it   -   Um
# 51332 is   .   Rloc- is   -   Um
# 51350 a   Today   Wtone a   today   Wform
# 51351 days   Today   Wtone days   today   Wform
# 51401 is   has not been   Vt is   , and there is no assurance that with the installing of this surveillance technology ,   Trans
# 51405 with   being easily replaced   Wci with   , and there is no assurance that with the installing of this surveillance technology ,   Trans
# 51407 installing   installation   Wform installing   , and there is no assurance that with the installing of this surveillance technology ,   Trans
# 51560 i   .   Um i   -   WOinc
# 51566 the   -   ArtOrDet the   -   WOinc
# 51569 the   make will incur some cost ,   WOinc the   -   WOinc
# 51570 government   is   SVA government   -   WOinc
# 51572 we   public spending on the aged should not be limited   Wtone we   -   WOinc
# 51574 be   -   Rloc- be   -   WOinc
# 51575 able   -   Rloc- able   -   WOinc
# 51577 meet   -   Rloc- meet   -   WOinc
# 51596 our   the   Wtone our   the   Wtone
# 51622 we   -   Um we   -   Rloc-
# 52062 elder   aged   Others elder   elderly   Wci
# 52076 need   needs   Nn need   -   Um
# 52100 of   in   Prep of   -   Um
# 52130 age   . The government will match the savings of every child dollar-for-dollar , up to the age of six   Srun age   a situation in which   Wci
# 52242 way   -   Rloc- way   Here   Wci
# 52282 number   -   Rloc- number   a drop in the   Wci
# 52305 -   who   Pref -   who   Trans
# 52320 general   Using publication   Wci general   have been   Vt
# 52455 the   -   ArtOrDet the   -   Rloc-
# 52543 -   and   Trans -   C )   Mec
# 52580 the   -   Um the   are   Vt
# 52612 time   phase to phase   Wci time   more advanced   Wci
# 52613 to   phase to phase   Wci to   more advanced   Wci
# 52618 is   The fact that `` Families saw the disease destroy their loved ones ' ability to feel , think , and move '' ( MedicineNet.com , n.d. , p.3 ) indicates   Others is   -   Rloc-
# 52619 that   -   Rloc- that   -   Rloc-
# 52650 country   -   Rloc- country   -   Rloc-
# 52664 cooled   lead-cooled   Mec cooled   lead-cooled   Mec
# 52757 kind   kinds   Nn kind   kinds   Nn
# 52808 ageing   -   Um ageing   the aging   ArtOrDet
# 52812 's   the Singapore   Wci 's   the Singapore Government   ArtOrDet
# 52830 -   the   ArtOrDet -   that are   Ssub
# 52842 a   -   Um a   , which is a scarce resource , as a form of energy   WOinc
# 52843 form   -   Um form   , which is a scarce resource , as a form of energy   WOinc
# 52845 energy   -   Cit energy   , which is a scarce resource , as a form of energy   WOinc
# 52846 ,   -   Rloc- ,   , which is a scarce resource , as a form of energy   WOinc
# 52847 which   Around   Rloc- which   , which is a scarce resource , as a form of energy   WOinc
# 52848 is   costs   SVA is   , which is a scarce resource , as a form of energy   WOinc
# 52890 {   -   Cit {   -   Cit
# 52891 http   citation   Cit http   -   Cit
# 52895 [   -   Cit [   -   Cit
# 52896 hyperlink   -   Cit hyperlink   -   Cit
# 52897 :   -   Cit :   -   Cit
# 52898 http   -   Cit http   -   Cit
# 52951 it   -   Rloc- it   -   Rloc-
# 53049 to   its   Pform to   -   ArtOrDet
# 53094 lives   -   Um lives   -   Um
# 53128 -   an   ArtOrDet -   an   Nn
# 53158 -   the   ArtOrDet -   a   ArtOrDet
# 53180 turn   , and in turn   ArtOrDet turn   -   Rloc-
# 53199 focusing   this report will focus   Wtone focusing   this essay will focus on the   Wtone
# 53363 out   up   Wci out   up   Wci
# 53374 to   -   Rloc- to   -   Rloc-
# 53375 the   -   Rloc- the   -   Rloc-
# 53388 -   the   ArtOrDet -   the   ArtOrDet
# 53393 ,   -   Trans ,   -   Rloc-
# 53626 health   -   Um health   -   Rloc-
# 53627 care   health care for the aged should be included as part of the public expenditure fund   WOinc care   -   Rloc-
# 53628 for   -   Um for   -   Rloc-
# 53629 the   -   Um the   -   Rloc-
# 53676 have   having   Spar have   -   Rloc-
# 53730 the   the world   ArtOrDet the   -   ArtOrDet
# 53947 term   terms   Nn term   to   Wci
# 53987 the   -   ArtOrDet the   -   ArtOrDet
# 53991 research   -   Wci research   researches   Nn
# 54122 depend   -   Um depend   provide   Wci
# 54294 leading   , this leads   Srun leading   lead   Rloc-
# 54336 work   employable   Wci work   employable   Wci
# 54337 age   employable   Wci age   employable   Wci
# 54378 -   with   Spar -   the   Vt
# 54522 amount   amounts   Nn amount   -   Rloc-
# 54523 of   -   Um of   -   Rloc-
# 54541 -   the   ArtOrDet -   an   ArtOrDet
# 54556 with   -   Prep with   -   Vt
# 54561 it   these differences   Pref it   not   Wci
# 54562 does   -   Um does   not   Wci
# 54563 not   Imagine a situation in which without sufficient support from the government , the aged become a burden to their families..   Wci not   not   Wci
# 54564 mean   Imagine a situation in which without sufficient support from the government , the aged become a burden to their families..   Wci mean   not   Wci
# 54584 the   -   ArtOrDet the   -   ArtOrDet
# 54679 -   the   ArtOrDet -   the   ArtOrDet
# 54834 country   -   Rloc- country   -   Rloc-
# 54854 economics   economies   Wform economics   economy   Wform
# 54860 -   in   Prep -   in   Others
# 1222

# %%
print(count)
# Out:
# 1222
